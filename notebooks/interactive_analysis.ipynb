# %%
# Load libraries
import pandas as pd
import matplotlib.pyplot as plt
import sys
import os

# Add root directory to sys.path
root_dir = os.path.abspath(os.path.join(os.getcwd(), ".."))
sys.path.append(root_dir)

from scripts.funds_analysis import load_fund_data, analyze_key_metrics, plot_metrics

# Load Data
file_path = "../data/synthetic_fund_data.csv"
df = load_fund_data(file_path)

# Analyze Data
analyze_key_metrics(df)

# Visualize Metrics
plot_metrics(df)
# Out:
# Key Metrics Summary:
#          IRR (%)       MOIC
# count  10.000000  10.000000
# mean   12.057205   2.230927
# std     6.532129   0.539877
# min     5.141326   1.223877
# 25%     6.153017   1.923037
# 50%    11.326323   2.127046
# 75%    16.798671   2.667058
# max    24.475110   2.969816
